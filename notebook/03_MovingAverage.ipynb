# %%
import pandas as pd
from statsmodels.tsa.arima_model import ARMA
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import statsmodels.api as sm

import seaborn as sns
#plt.rcParams['figure.dpi'] = 100

# %%
data = pd.read_csv('../data/examples/shampoo.dat', header=None, names=['actual'])
data['MA3'] = data['actual'].rolling(window=3, center=True).mean()
data['MA5'] = data['actual'].rolling(window=5, center=True).mean()

data.plot()

# %%
ma_3
# Out:
#              0
# 0          NaN
# 1   198.333333
# 2   149.433333
# 3   160.900000
# 4   156.033333
# 5   193.533333
# 6   208.266667
# 7   216.366667
# 8   180.066667
# 9   217.400000
# 10  215.100000
# 11  238.900000
# 12  176.566667
# 13  184.633333
# 14  210.966667
# 15  224.933333
# 16  250.566667
# 17  234.800000
# 18  272.200000
# 19  273.166667
# 20  338.366667
# 21  325.333333
# 22  342.800000
# 23  315.500000
# 24  374.133333
# 25  365.333333
# 26  398.533333
# 27  385.500000
# 28  426.000000
# 29  471.400000
# 30  473.500000
# 31  555.033333
# 32  521.633333
# 33  579.533333
# 34  567.833333
# 35         NaN
